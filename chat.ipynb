# %%
import requests
import json

api_key = "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"
response = requests.post("https://api.openai.com/v1/chat/completions",
             headers = {'Authorization': 'Bearer '+ api_key,
                        'Content-Type': 'application/json'},
             data = json.dumps(
                    {"model": "gpt-3.5-turbo",
                     "messages": [{"role": "user", 
                                   "content": """ 'i ve been playing flight simulators dogfighting games for over years. i can honestly say this is the most frustrating i ve ever played. the controls are like lead and the missions become difficult right off the bat. poor instructions and objective add to the frustration, as you will spend a great deal of time just figuring out wtf you are supposed to do. i had to resort to walkthroughs just to survive the training mission. the game is also buggy and froze on me more than once in the brief weeks i wasted my time on it. save your money and check out the ace combat series instead.' 
                                   Generate 4 augmented samples for this sentence. Output only the augmented sentences. """}]}))
res = json.loads(response.text)['choices'][0]["message"]["content"]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 5
#       2 import json
#       4 api_key = "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"
# ----> 5 response = requests.post("https://api.openai.com/v1/chat/completions",
#       6              headers = {'Authorization': 'Bearer '+ api_key,
#       7                         'Content-Type': 'application/json'},
#       8              data = json.dumps(
#       9                     {"model": "gpt-3.5-turbo",
#      10                      "messages": [{"role": "user",
# ...

# %%
aug_sen = res.split('\n')
aug_sentences = [' '.join(aug.split(' ')[1:]) for aug in aug_sen]
# Out:
# 'As someone who has been playing flight simulators and dogfighting games for more than a decade, I have to say that this is, without a doubt, the most exasperating one I have ever come across.'

# %%
output = None
input = './training_dataset/train_100.csv'
from os.path import dirname, basename, join
output = join(dirname(input), 'chat_' + basename(input))
api_key = "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"

def get_api(sentence):
    content = "\'" + sentence + "\'" + " Generate 4 complete augmented samples for this paragraph as a whole, output only the augmented paragraph. Do not add quotation mark at both ends. "
    response = requests.post("https://api.openai.com/v1/chat/completions",
             headers = {'Authorization': 'Bearer '+ api_key,
                        'Content-Type': 'application/json'},
             data = json.dumps(
                    {"model": "gpt-3.5-turbo",
                     "messages": [{"role": "user", 
                                   "content": content}]}))
    res = json.loads(response.text)['choices'][0]["message"]["content"]
    aug_sen = res.split('\n')
    aug_sentences = [' '.join(aug.split(' ')[1:]) for aug in aug_sen]
    return aug_sentences
    
# aug_list = []

def gen_chat(train_orig, output_file, num_aug=4):

    writer = open(output_file, 'w')
    lines = open(train_orig, 'r').readlines()
    writer.write('score' + "," + 'text' + '\n')

    for i, line in enumerate(lines):
        if i < 92:
            continue
        parts = line[:-1].split(',', 1)
        label = parts[0]
        sentence = parts[1]
        aug_sentences = get_api(sentence)
        aug_list.append(aug_sentences)
        for aug_sentence in aug_sentences:
            print(aug_sentence)
            writer.write(label + "," + aug_sentence + '\n')

    writer.close()
    # print("generated augmented sentences with eda for " + train_orig + " to " + output_file + " with num_aug=" + str(num_aug))

gen_chat(input, output, num_aug=4)
# Out:
# In all honesty, there is no worse bundle and game out there. If you are considering buying this, think again because it is an absolute disappointment in every aspect. The graphics and story are just downright appalling.
# Save yourself the trouble by not even thinking about purchasing this bundle and game. Believe me, you will regret it because it is hands down the worst game out there. The graphics and story are so terrible that it's cringe-worthy.
# Let me be clear, this bundle and game is an absolute disaster. Buying it would be a complete waste of your money and time because it is that bad. The graphics and story are a total eyesore that no one should have to suffer through.
# I cannot stress enough how terrible this bundle and game is. It is without a doubt the worst game you could ever buy. Do not even consider purchasing it because the graphics and story are unbearable and I strongly advise against it.
# ...

# %%
aug_list[92]
list_100 = aug_list.copy()
list_100.pop(92)
# Out:
# ['In all honesty, there is no worse bundle and game out there. If you are considering buying this, think again because it is an absolute disappointment in every aspect. The graphics and story are just downright appalling.',
#  "Save yourself the trouble by not even thinking about purchasing this bundle and game. Believe me, you will regret it because it is hands down the worst game out there. The graphics and story are so terrible that it's cringe-worthy.",
#  'Let me be clear, this bundle and game is an absolute disaster. Buying it would be a complete waste of your money and time because it is that bad. The graphics and story are a total eyesore that no one should have to suffer through.',
#  'I cannot stress enough how terrible this bundle and game is. It is without a doubt the worst game you could ever buy. Do not even consider purchasing it because the graphics and story are unbearable and I strongly advise against it.']

# %%
input = './training_dataset/train_100.csv'
lines = open(input, 'r').readlines()
labels = []

for i, line in enumerate(lines):
    parts = line[:-1].split(',', 1)
    label = parts[0]
    labels.append(label)

# %%
property
# Out:
# 101

# %%
writer = open(output, 'w')
writer.write('score' + "," + 'text' + '\n')
i = 1
for sentences in list_100:
    for s in sentences:
        if s != '':
            writer.write(labels[i] + "," + s + '\n')
    i += 1
writer.close()

# %%
len(list_100)
for sentences in list_100:
    for s in sentences:
        if s != '':
            print(s)
# Out:
# I'm really enjoying this game so far, but unfortunately I've hit a roadblock on one of the missions.
# Although the game itself is quite enjoyable, I'm currently stuck on a mission and unable to progress any further.
# This game has been a great source of entertainment, but I've run into a bit of a problem with a particular mission that I can't seem to complete.
# While I do believe this game is good, my progress has come to a halt thanks to a challenging mission that has me stuck.
# ...

# %%
list_100.pop(92)
len(list_100)
len(aug_list)
# Out:
# 92

# %%
list_100 = aug_list
len(list_100)
# Out:
# 92

# %%
import pandas as pd

pd.read_csv('./training_dataset/chat_train_20.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[84], line 3
#       1 import pandas as pd
# ----> 3 pd.read_csv('./training_dataset/chat_train_20.csv')
#
# File ~/mambaforge/envs/nlp/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
file = './training_dataset/chat_train_20.csv'
writer = open(file, 'w')
lines = open(file, 'r').readlines()
writer.write('score' + ", " + 'text' + '\n')
for i, line in enumerate(lines):
    parts = line[:-1].split(', ', 1)
    clean = parts[1].strip().replace('"', '')
    print(clean)
    writer.write(parts[0] + "," + clean + '\n')

writer.close()

# %%
import re
from nltk.stem import PorterStemmer
import nltk

def clean(raw):
    """ Remove hyperlinks and markup """
    result = re.sub("<[a][^>]*>(.+?)</[a]>", 'Link.', raw)
    result = re.sub('&gt;', "", result)
    result = re.sub('&#x27;', "'", result)
    result = re.sub('&quot;', '"', result)
    result = re.sub('&#x2F;', ' ', result)
    result = re.sub('<p>', ' ', result)
    result = re.sub('</i>', '', result)
    result = re.sub('&#62;', '', result)
    result = re.sub('<i>', ' ', result)
    result = re.sub("\n", '', result)
    return result

def remove_num(texts):
   output = re.sub(r'\d+', '', texts)
   return output

def deEmojify(x):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'', x)

def unify_whitespaces(x):
    cleaned_string = re.sub(' +', ' ', x)
    return cleaned_string 

def remove_symbols(x):
    cleaned_string = re.sub(r"[^a-zA-Z0-9?!.,]+", ' ', x)
    return cleaned_string

def remove_punctuation(text):
    final = "".join(u for u in text if u not in ("?", ".", ";", ":",  "!",'"',','))
    return final

stop=set(stopwords.words("english"))
stemmer=PorterStemmer()
# lemma=WordNetLemmatizer()

def remove_stopword(text):
   text=[word.lower() for word in text.split() if word.lower() not in stop]
   return " ".join(text)

from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
def Stemming(text):
   stem=[]
   stopword = stopwords.words('english')
   snowball_stemmer = SnowballStemmer('english')
   word_tokens = nltk.word_tokenize(text)
   stemmed_word = [snowball_stemmer.stem(word) for word in word_tokens]
   stem=' '.join(stemmed_word)
   return stem

def cleaning(df,review):
    df[review] = df[review].apply(clean)
    df[review] = df[review].apply(deEmojify)
    df[review] = df[review].str.lower()
    df[review] = df[review].apply(remove_num)
    df[review] = df[review].apply(remove_symbols)
    df[review] = df[review].apply(remove_punctuation)
    df[review] = df[review].apply(remove_stopword)
    df[review] = df[review].apply(unify_whitespaces)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 44
#      41     final = "".join(u for u in text if u not in ("?", ".", ";", ":",  "!",'"',','))
#      42     return final
# ---> 44 stop=set(stopwords.words("english"))
#      45 stemmer=PorterStemmer()
#      46 # lemma=WordNetLemmatizer()
#
# NameError: name 'stopwords' is not defined
